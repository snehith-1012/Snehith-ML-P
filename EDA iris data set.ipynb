# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib.inline
import seaborn as sns
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
df=pd.read_csv(r'C:\Users\admin\machine learning codebasics\archive (1)\IRIS.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.size
# Out:
# 750

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.species.value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: species, dtype: int64

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# ###### by the above heatmap we can say there were no null values in the given data sert

# %% [markdown]
# ##### Here, all the three classes have equal data points i.e 50 which clearly shows that it is a balanced dataset.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df[df.species=='Iris-setosa'].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000

# %%
df[df.species=='Iris-versicolor'].describe().head()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000

# %%
df[df.species=='Iris-virginica'].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %% [markdown]
# ##### here we  can clearly see that the average petal width is different for each type of flower, let us see these through plotting

# %%
plt.scatter(df.sepal_length,df.sepal_width)

# %%
plt.scatter(df[df.species=='Iris-virginica'].sepal_length,df[df.species=='Iris-virginica'].sepal_width,c='g')
plt.scatter(df[df.species=='Iris-versicolor'].sepal_length,df[df.species=='Iris-versicolor'].sepal_width,c='r')
plt.scatter(df[df.species=='Iris-setosa'].sepal_length,df[df.species=='Iris-setosa'].sepal_width,c='b')

# %% [markdown]
# #### by plotting we can see the flowers are forming different clusters based on sepal length and sepal width

# %%
plt.scatter(df[df.species=='Iris-virginica'].petal_length,df[df.species=='Iris-virginica'].petal_width,c='g')
plt.scatter(df[df.species=='Iris-versicolor'].petal_length,df[df.species=='Iris-versicolor'].petal_width,c='r')
plt.scatter(df[df.species=='Iris-setosa'].petal_length,df[df.species=='Iris-setosa'].petal_width,c='b')

# %% [markdown]
# ### wrt to sepal width vs sepal length the flowers can be easily classified

# %%
sns.pairplot(df, hue="species")

# %% [markdown]
# #### from the above pairplot we can say setosa is easily classified in every subplot

# %% [markdown]
# #### as many points of versicolor and verginica are over lapping we can do some more analysis

# %%
sns.distplot(df[df.species=='Iris-setosa'].petal_length)

# %%
sns.distplot(df[df.species=='Iris-versicolor'].petal_length)

# %%
sns.distplot(df[df.species=='Iris-virginica'].petal_length)

# %%
sns.distplot(df[df.species=='Iris-virginica'].petal_length)
sns.distplot(df[df.species=='Iris-versicolor'].petal_length)
sns.distplot(df[df.species=='Iris-setosa'].petal_length)

# %%
sns.FacetGrid(df, hue="species",height=4) \
   .map(sns.distplot, "petal_length") \
   .add_legend()

# %% [markdown]
# ###### the gaussian distribution of petal_lengths of versicolor is right-skewed and virginica is left-skewed

# %%
sns.FacetGrid(df, hue="species", height=4) \
   .map(sns.distplot, "petal_width") \
   .add_legend()

# %% [markdown]
# #### based on petal_width flowers can be easily classified compared to petal_length  (petal_width>petal_length) (priority for classification)

# %%
sns.FacetGrid(df, hue="species", height=4) \
   .map(sns.distplot, "sepal_width") \
   .add_legend()

# %%
sns.FacetGrid(df, hue="species", height=4) \
   .map(sns.distplot, "sepal_length") \
   .add_legend()

# %% [markdown]
# #### based on sepal_length flowers can be easily classified compared to sepal_width  (sepal_width<sepal_length) (priority for classification)

# %%
def avg_of_sp(k):
    print(df[df.species==k].petal_length.mean())
    print(df[df.species==k].petal_width.mean())
    print(df[df.species==k].sepal_length.mean())
    print(df[df.species==k].sepal_width.mean())

# %%
for i in df.species.unique():
    print(i)
    avg_of_sp(i)
    print()
# Out:
# Iris-setosa
# 1.464
# 0.2439999999999999
# 5.005999999999999
# 3.4180000000000006
#
# Iris-versicolor
# 4.26
# 1.3259999999999998
# 5.936
# 2.7700000000000005
#
# Iris-virginica
# 5.552
# 2.026
# 6.587999999999998
# 2.9739999999999998

# %%
sns.boxplot(x="species", y="petal_length", data=df)

# %%
sns.boxplot(x="species", y="petal_width", data=df)

# %%
sns.boxplot(x="species", y="sepal_length", data=df)

# %%
sns.boxplot(x="species", y="sepal_width", data=df)

# %% [markdown]
# ### every where setosa is easily classified where as versicolor and virginca has some common bound points bu the means of  attributes of these two flowers are different and seperable

# %% [markdown]
# ### the outliers that are identified in virginca and versicolor can cause some problem in classifying them

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df.drop('species',axis=1))

# %%
scaled_data = pd.DataFrame(scaled_data, columns=['sepal_length','sepal_width','petal_length','petal_width'])
scaled_data.head()
scaled_data['species']=df['species']

# %%
df=scaled_data

# %%
plt.scatter(df[df.species=='Iris-virginica'].petal_length,df[df.species=='Iris-virginica'].petal_width,c='g')
plt.scatter(df[df.species=='Iris-versicolor'].petal_length,df[df.species=='Iris-versicolor'].petal_width,c='r')
plt.scatter(df[df.species=='Iris-setosa'].petal_length,df[df.species=='Iris-setosa'].petal_width,c='b')
